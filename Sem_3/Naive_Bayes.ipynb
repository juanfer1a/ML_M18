# %% [markdown]
# # **Naive Bayes Classifier**

# %% [markdown]
# Iris dataset [Aquí](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) \\
# Naive Bayes documentation [Aquí](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris # Iris dataset

# %%
iris = load_iris() # Load the iris dataset
iris_x = iris.data[:, 0:2] # Features. We'll pick 2
iris_y = iris.target # Labels
iris_names = iris.target_names
iris_features = iris.feature_names[0:2]

# Print shapes
print ( iris_x.shape, iris_y.shape, '\n', iris_names, '\n', iris_features)
# Out:
# (150, 2) (150,)
#  ['setosa' 'versicolor' 'virginica']
#  ['sepal length (cm)', 'sepal width (cm)']

# %%
# Instance GaussianNB object
naive_bayes = GaussianNB()

# Training
naive_bayes.fit( iris_x , iris_y )
# Out:
# GaussianNB()

# %%
## Plot decision boundaries
offset = 5
h_min, h_max = iris_x[:, 0].min()-offset, iris_x[:, 0].max()+offset
v_min, v_max = iris_x[:, 1].min()-offset, iris_x[:, 1].max()+offset

h_grid, v_grid = np.meshgrid(np.linspace(h_min, h_max, 300), np.linspace(v_min, v_max, 300))

predictions = naive_bayes.predict( np.c_[h_grid.ravel(), v_grid.ravel()] )
predictions = predictions.reshape(h_grid.shape)
print(h_grid.shape, v_grid.shape, predictions.shape)
# Out:
# (300, 300) (300, 300) (300, 300)

# %%
_, ax = plt.subplots(figsize=(12,8))

ax.pcolormesh(h_grid, v_grid, predictions, cmap='Paired')
ax.contour(h_grid, v_grid, predictions, colors='k', linestyles='--')
ax.scatter(iris_x[:,0], iris_x[:,1], c=iris_y, edgecolors='k', cmap='Paired')

ax.set_xlabel(iris_features[0])
ax.set_ylabel(iris_features[1])
# ax.set_xticks([]), ax.set_yticks([])
plt.tight_layout()

# %% [markdown]
# ## On real data - Fruits dataset
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
fruit_data = _ # Load the fruits dataset
fruits_x = _  # Features. We'll pick 2
fruits_y = _  # Labels

# Convert everything to a np array
fruits_x, fruits_y = np.asarray(fruits_x), np.asarray(fruits_y)

# Print shapes
print ( _ )

# %%
# Instance GaussianNB object
naive_bayes = GaussianNB()

# Training
 _ #(num_samples, Features)

# %%
## Plot decision boundaries
_
