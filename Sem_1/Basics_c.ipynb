# %%
import numpy as np
np.random.seed(5)

# %%
array_1 = np.array([5,7,6,8,1,3,4], dtype=np.int32)
array_2 = np.random.randint(10,30,len(array_1))

print (array_1, array_2)
print (array_1.shape, array_2.shape)
print (type(array_1), array_1.dtype)
# Out:
# [5 7 6 8 1 3 4] [27 17 26 22 23 21 11]
# (7,) (7,)
# <class 'numpy.ndarray'> int32

# %%
print (array_1 + array_2)
# Out:
# [32 24 32 30 24 24 15]

# %%
print (array_1 * array_2)
print (np.dot(array_1, array_2))
print (np.dot(array_2, array_1))
# Out:
# [135 119 156 176  23  63  44]
# 716
# 716

# %% [markdown]
# ## Procesamiento de imagenes

# %%
from PIL import Image
# import PIL
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("/content/lena.jpg")
plt.imshow(image)

# %%
print (type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
image = np.array(image)
print (type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(image)
print (image.shape)
# Out:
# (300, 400, 3)

# %%
image = Image.open("/content/lena.jpg")
image = np.array(image)
# image[0:50, 50:100, 0] = 255
# image[0:50, 50:100, 2] = 255
image[0:50, 50:100] = 0
plt.imshow(image)

# %%
print (image[50:100, 100:150])

# %%
lena_face = image[100:200, 180:260, :]
plt.imshow(lena_face)
print (lena_face.shape)
# Out:
# (100, 80, 3)

# %%
image = Image.open("/content/lena.jpg")
image = np.array(image)
image[100:200, 300:380, :] = lena_face
plt.imshow(image)
